# %% [markdown]
# **Project plan**
#
# *Data preprocessing
# 1. Detect the english tweets
# https://github.com/rfk/pyenchant
#
# *Sentiment Analysis*
# 1. Find a sentiment analysis NN to rate last tweets
# 2. DONE - Extract the emoji's and incorporate the emoji sentiment <br>
# https://stackoverflow.com/questions/43852668/using-collections-counter-to-count-emojis-with-different-colors<br>
# https://stackoverflow.com/questions/48340622/extract-all-emojis-from-string-and-ignore-fitzpatrick-modifiers-skin-tones-etc
#
# *Build a pipeline for similar tweet recommender*
# 1. Implement class for recommend engine
# 2. Build a pipeline for word embedding, vectorizing, and recommendation
# 3. Try out Glove, Google embedding.. etc

# %%
import string
import emoji
import regex
import pickle
import re
import enchant
import math

import numpy as np
import pandas as pd
import vaderSentiment

import matplotlib.pyplot as plt

from itertools import compress
from tqdm import tqdm_notebook
from termcolor import colored


# gensim
from gensim import corpora, models, similarities, matutils
# sklearn
from sklearn import datasets
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.feature_extraction import text
from sklearn.decomposition import NMF, TruncatedSVD
import nltk.sentiment.vader
from sklearn.neighbors import NearestNeighbors
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from nltk.stem import WordNetLemmatizer
    
from sklearn.cluster import KMeans
from nltk.tokenize import word_tokenize
# logging for gensim (set to INFO)

import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %matplotlib inline

# %%
twitter = pd.read_csv("./customer-support-on-twitter/twcs.csv")

# %% [markdown]
# ### Exclude tweets with non-English characters

# %%
def fixContractions(text):
    with open('./data/helper/contraction_list.pkl', 'rb') as picklefile:
        cList = pickle.load(picklefile)
    for word in text.split():
        if word.lower() in cList:
            text = text.replace(word, cList[word.lower()])
    return text

def clean_text(text):
    text = text.lower()
    text = re.sub(r'https:\/\/t.co\/\w{10}', '', text) # Remove URL link
    text = re.sub(r'@\w+', '', text) # Remove @account
    text = fixContractions(text) # Expand contractions
    return text

# %%
twitter['text'] = twitter['text'].apply(lambda x:clean_text(x))

# %%
twitter.head()
# Out:
#    tweet_id   author_id  inbound                      created_at  \
# 0         1  sprintcare    False  Tue Oct 31 22:10:47 +0000 2017
# 1         2      115712     True  Tue Oct 31 22:11:45 +0000 2017
# 2         3      115712     True  Tue Oct 31 22:08:27 +0000 2017
# 3         4  sprintcare    False  Tue Oct 31 21:54:49 +0000 2017
# 4         5      115712     True  Tue Oct 31 21:49:35 +0000 2017
#
#                                                 text response_tweet_id  \
# 0   i understand. i would like to assist you. we ...                 2
# 1                  and how do you propose we do that               NaN
# 2   i have sent several private messages and no o...                 1
# 3   please send us a private message so that we c...                 3
# 4                                             i did.                 4
#
#    in_response_to_tweet_id
# 0                      3.0
# 1                      1.0
# 2                      4.0
# 3                      5.0
# 4                      6.0

# %%
def get_emoji_free_text(text):
    text = text.replace(u'\u200d', '')
    allchars = [str for str in text]
    emoji_list = [c for c in allchars if c in emoji.UNICODE_EMOJI]
    clean_text = ' '.join([str for str in text.split() if not any(i in str for i in emoji_list)])
    if (len(emoji_list) == 0):
        return np.NaN, clean_text
    else:
        return emoji_list, clean_text

# %%
twitter[['emoji','text']] = twitter['text'].apply(lambda x:pd.Series(get_emoji_free_text(x)))

# %%
twitter.iloc[100:200,:]
# Out:
#      tweet_id        author_id  inbound                      created_at  \
# 100       180           115743     True  Tue Oct 31 08:17:37 +0000 2017
# 101       182   AskPlayStation    False  Tue Oct 31 22:09:50 +0000 2017
# 102       183           115745     True  Tue Oct 31 22:06:44 +0000 2017
# 103       184   AskPlayStation    False  Tue Oct 31 22:05:06 +0000 2017
# 104       185           115745     True  Tue Oct 31 08:14:24 +0000 2017
# 105       187   AskPlayStation    False  Tue Oct 31 22:06:34 +0000 2017
# 106       188           115746     True  Tue Oct 31 07:58:24 +0000 2017
# 107       190  marksandspencer    False  Tue Oct 31 21:54:47 +0000 2017
# 108       191           115747     True  Tue Oct 31 18:29:42 +0000 2017
# 109       192  marksandspencer    False  Tue Oct 31 21:48:52 +0000 2017
# 110       193           115748     True  Tue Oct 31 17:58:45 +0000 2017
# 111       194  marksandspencer    False  Tue Oct 31 21:46:06 +0000 2017
# 112       195           115749     True  Tue Oct 31 23:40:34 +0000 2017
# 113       199  marksandspencer    False  Wed Nov 01 13:42:19 +0000 2017
# 114       200           115749     True  Wed Nov 01 15:54:37 +0000 2017
# 115       196           115749     True  Tue Oct 31 23:35:13 +0000 2017
# 116       197           115749     True  Tue Oct 31 23:38:53 +0000 2017
# 117       198           115749     True  Tue Oct 31 17:56:34 +0000 2017
# 118       201  marksandspencer    False  Tue Oct 31 21:45:28 +0000 2017
# 119       202           115750     True  Tue Oct 31 20:20:57 +0000 2017
# 120       203   MicrosoftHelps    False  Tue Oct 31 22:08:00 +0000 2017
# 121       204           115751     True  Tue Oct 31 22:09:13 +0000 2017
# 122       205           115751     True  Tue Oct 31 22:04:20 +0000 2017
# 123       207   MicrosoftHelps    False  Tue Oct 31 22:04:21 +0000 2017
# 124       208           115752     True  Tue Oct 31 20:28:11 +0000 2017
# 125       209       ATVIAssist    False  Tue Oct 31 22:14:22 +0000 2017
# 126       210           115753     True  Tue Oct 31 19:54:00 +0000 2017
# 127       211       ATVIAssist    False  Tue Oct 31 22:09:50 +0000 2017
# 128       212           115756     True  Thu Nov 02 04:03:21 +0000 2017
# 129       214       ATVIAssist    False  Thu Nov 02 12:42:05 +0000 2017
# ..        ...              ...      ...                             ...
# 170       259        AdobeCare    False  Fri Nov 03 01:35:31 +0000 2017
# 171       260           115768     True  Fri Nov 03 05:29:47 +0000 2017
# 172       261        AdobeCare    False  Mon Nov 06 16:22:30 +0000 2017
# 173       262           115768     True  Mon Nov 06 16:23:56 +0000 2017
# 174       263        AdobeCare    False  Mon Nov 06 17:02:22 +0000 2017
# 175       265           115768     True  Mon Nov 06 17:04:37 +0000 2017
# 176       267        AdobeCare    False  Mon Nov 06 17:13:59 +0000 2017
# 177       266           115768     True  Mon Nov 06 17:04:00 +0000 2017
# 178       264        AdobeCare    False  Mon Nov 06 16:46:26 +0000 2017
# 179       268           115768     True  Mon Nov 06 16:54:02 +0000 2017
# 180       253           115768     True  Sun Oct 29 21:02:31 +0000 2017
# 181       269       AmazonHelp    False  Wed Nov 22 09:23:01 +0000 2017
# 182       270           115770     True  Wed Nov 22 09:24:30 +0000 2017
# 183       271           115770     True  Wed Nov 22 09:30:36 +0000 2017
# 184       273       AmazonHelp    False  Wed Nov 22 09:40:27 +0000 2017
# 185       274           115770     True  Wed Nov 22 09:44:04 +0000 2017
# 186       275       AmazonHelp    False  Wed Nov 22 10:06:26 +0000 2017
# 187       272           115770     True  Wed Nov 22 09:14:39 +0000 2017
# 188       276      XboxSupport    False  Sat Dec 02 18:06:03 +0000 2017
# 189       277           115771     True  Sat Dec 02 09:17:57 +0000 2017
# 190       278        AdobeCare    False  Tue Oct 31 22:01:52 +0000 2017
# 191       279           115772     True  Sat Oct 28 19:29:38 +0000 2017
# 192       280        AdobeCare    False  Tue Oct 31 22:03:13 +0000 2017
# 193       281           115773     True  Sat Oct 28 23:11:01 +0000 2017
# 194       282        AdobeCare    False  Tue Oct 31 22:00:12 +0000 2017
# 195       283           115774     True  Sat Oct 28 13:37:52 +0000 2017
# 196       284        AdobeCare    False  Tue Oct 31 21:54:16 +0000 2017
# 197       285           115775     True  Tue Oct 31 20:16:08 +0000 2017
# 198       287        AdobeCare    False  Thu Oct 26 19:03:22 +0000 2017
# 199       288           115776     True  Thu Oct 26 18:13:19 +0000 2017
#
#                                                   text response_tweet_id  \
# 100        so, what is the november ps plus free game?           178,181
# 101  glad to know that is downloading, please feel ...               NaN
# 102  it was when i would go to download it. i just ...               182
# 103  sorry for the inconvenience. do you see the da...               183
# 104  i bought lego star wars in the playstation sto...           184,186
# 105  glad to help. please share the details of this...               NaN
# 106  can i block a community from sending me invite...           187,189
# 107  glad you had fun, sarah! we heard count collin...               NaN
# 108                 we had to have a count colin xx...               190
# 109  we have let our team know we can do better, jo...               NaN
# 110  ‘ere , never mind avocado - how’s about ‘ave a...               192
# 111  we are only obligated to provide bags for un-p...       195,196,197
# 112  raw meat!!!! it’s does not say unwrapped raw m...               199
# 113  as our packaging is sufficient, any extra wrap...               200
# 114  i check with the gov office and legal. they st...               NaN
# 115  ou must charge at least 5p a bag (including va...               NaN
# 116  aren’t require charge 4 a bag: paper bags shop...               NaN
# 117  y do they charge you for a meat bag at collier...               194
# 118  love the aesthetic of your colin the 'creeperp...               NaN
# 119  excellent halloweening #countcolin #halloween ...               201
# 120  hello, josh! to get better assistance and supp...               204
# 121                              brilliant, thank you!               NaN
# 122  hi, having trouble making purchases on xbox on...           203,206
# 123  help is here. to assist you in recovering your...               NaN
# 124  i need assistance recovering 2 hotmail account...               207
# 125  it appears this has been removed. thanks for l...               NaN
# 126    umm someone is streaming wwii with 500+ viewers               209
# 127  no problem, let us know if you come across any...               212
# 128  i am trying to buy the digital deluxe edition ...               214
# 129  hello there. sorry for the late response. i am...               NaN
# ..                                                 ...               ...
# 170  sorry for this. let me request the expert to l...               260
# 171  ok. its been very frustrating. i have multiple...               261
# 172  hi jeffrey, we wanted to check if you had mana...               262
# 173  no its still broken. i deleted it and will pro...           263,264
# 174  jeffrey did you use the process listed in to d...           265,266
# 175  ill just wait for the next big update. ive was...               267
# 176  jeffrey i am sorry to hear that. if you face f...               NaN
# 177  yea ive done everything you guys told me to do...               NaN
# 178  hi there, i am looping our expert team to help...               268
# 179  you guys have been saying that for weeks now. ...               NaN
# 180  whats going on with your app. its totally stuc...               251
# 181  こんにちは、アマゾン公式です。fire tv stickが見れないというのは、どのような状況...           270,271
# 182                   ありがとうございます。 今、電話で主人が対応していただいてます。               NaN
# 183  電話で対応してもらいましたが改良されませんでした。 保証期間も過ぎてるので買い直しになるんで...               273
# 184  カスタマーサービスにてお問い合わせ済みとのことで、お手数をおかけいたしました。リプライいただ...               274
# 185                                  こちらこそありがとうございました。               275
# 186     恐れ入ります。至らない点も多々あるかとは存じますが、今後ともどうぞよろしくお願いします。et               NaN
# 187                                                                  269
# 188  hi, you can change your microsoft account emai...               NaN
# 189  can i change me sons xbox live account to his ...               276
# 190  hi there, lightroom 7.0.1 update was launched ...               NaN
# 191  did u release an update today for lightroom cl...               278
# 192  hi there, please dm us you adobe id so that we...               NaN
# 193  please tell me why my has expired, but i’m sti...               280
# 194  hi there, you may suggest it as a feature requ...               NaN
# 195  are there any plans to add a fast crop mode fo...               282
# 196  thanks for sharing the file, we will get back ...               NaN
# 197  it’s intermittent for me. this file fails reli...           284,286
# 198  unfortunately, we are not able to reproduce it...               285
# 199  seems pretty widespread: do not mean to be a j...               287
#
#      in_response_to_tweet_id      emoji
# 100                      NaN        NaN
# 101                    183.0        NaN
# 102                    184.0        NaN
# 103                    185.0        NaN
# 104                      NaN        NaN
# 105                    188.0        NaN
# 106                      NaN        NaN
# 107                    191.0        NaN
# 108                      NaN        [💛]
# 109                    193.0        NaN
# 110                      NaN        [🥑]
# 111                    198.0        NaN
# 112                    194.0        NaN
# 113                    195.0        NaN
# 114                    199.0        NaN
# 115                    194.0        NaN
# 116                    194.0        [🌷]
# 117                      NaN        NaN
# 118                    202.0  [🐛, 🦋, 👻]
# 119                      NaN        [👌]
# 120                    205.0        NaN
# 121                    203.0        NaN
# 122                      NaN        NaN
# 123                    208.0        NaN
# 124                      NaN        NaN
# 125                    210.0        NaN
# 126                      NaN        NaN
# 127                    213.0        NaN
# 128                    211.0        NaN
# 129                    212.0        NaN
# ..                       ...        ...
# 170                    258.0        NaN
# 171                    259.0        NaN
# 172                    260.0        NaN
# 173                    261.0        NaN
# 174                    262.0        NaN
# 175                    263.0        NaN
# 176                    265.0        NaN
# 177                    263.0        NaN
# 178                    262.0        NaN
# 179                    264.0        NaN
# 180                      NaN        NaN
# 181                    272.0        NaN
# 182                    269.0        NaN
# 183                    269.0        NaN
# 184                    271.0        NaN
# 185                    273.0        NaN
# 186                    274.0        NaN
# 187                      NaN        [😢]
# 188                    277.0        NaN
# 189                      NaN        NaN
# 190                    279.0        NaN
# 191                      NaN        NaN
# 192                    281.0        NaN
# 193                      NaN        NaN
# 194                    283.0        NaN
# 195                      NaN        NaN
# 196                    285.0        NaN
# 197                    287.0        NaN
# 198                    288.0        NaN
# 199                    289.0        NaN
#
# [100 rows x 8 columns]

# %%
test = twitter.loc[110, 'emoji']

# %%
type(test) == float
# Out:
# False

# %%
with open('./data/processed/tweets_step1_emoji_extracted.pkl', 'wb')as picklefile:
    pickle.dump(twitter, picklefile)

# %%
with open('./data/processed/tweets_step1_emoji_extracted.pkl', 'rb')as picklefile:
    twitter = pickle.load(picklefile)
twitter.head(100)
# Out:
#     tweet_id       author_id  inbound                      created_at  \
# 0          1      sprintcare    False  Tue Oct 31 22:10:47 +0000 2017
# 1          2          115712     True  Tue Oct 31 22:11:45 +0000 2017
# 2          3          115712     True  Tue Oct 31 22:08:27 +0000 2017
# 3          4      sprintcare    False  Tue Oct 31 21:54:49 +0000 2017
# 4          5          115712     True  Tue Oct 31 21:49:35 +0000 2017
# 5          6      sprintcare    False  Tue Oct 31 21:46:24 +0000 2017
# 6          8          115712     True  Tue Oct 31 21:45:10 +0000 2017
# 7         11      sprintcare    False  Tue Oct 31 22:10:35 +0000 2017
# 8         12          115713     True  Tue Oct 31 22:04:47 +0000 2017
# 9         15      sprintcare    False  Tue Oct 31 20:03:31 +0000 2017
# 10        16          115713     True  Tue Oct 31 20:00:43 +0000 2017
# 11        17      sprintcare    False  Tue Oct 31 19:59:13 +0000 2017
# 12        18          115713     True  Tue Oct 31 19:56:01 +0000 2017
# 13        19      sprintcare    False  Tue Oct 31 22:10:10 +0000 2017
# 14        20          115715     True  Tue Oct 31 22:03:34 +0000 2017
# 15        21    Ask_Spectrum    False  Tue Oct 31 22:14:37 +0000 2017
# 16        22          115716     True  Tue Oct 31 22:16:48 +0000 2017
# 17        25    Ask_Spectrum    False  Tue Oct 31 22:18:28 +0000 2017
# 18        26          115716     True  Tue Oct 31 22:19:56 +0000 2017
# 19        27    Ask_Spectrum    False  Tue Oct 31 22:21:26 +0000 2017
# 20        23          115716     True  Tue Oct 31 22:16:05 +0000 2017
# 21        24          115716     True  Tue Oct 31 22:13:02 +0000 2017
# 22        28    Ask_Spectrum    False  Tue Oct 31 22:05:37 +0000 2017
# 23        29          115716     True  Tue Oct 31 22:01:35 +0000 2017
# 24        30    Ask_Spectrum    False  Tue Oct 31 22:12:09 +0000 2017
# 25        31          115717     True  Tue Oct 31 22:06:54 +0000 2017
# 26        32    Ask_Spectrum    False  Tue Oct 31 22:10:08 +0000 2017
# 27        33          115718     True  Tue Oct 31 22:06:56 +0000 2017
# 28        34  VerizonSupport    False  Tue Oct 31 22:13:33 +0000 2017
# 29        35          115719     True  Tue Oct 31 22:49:16 +0000 2017
# ..       ...             ...      ...                             ...
# 70        78          115732     True  Tue Oct 31 22:01:40 +0000 2017
# 71        79  ChipotleTweets    False  Tue Oct 31 22:11:12 +0000 2017
# 72        80          115733     True  Tue Oct 31 22:01:32 +0000 2017
# 73        81  ChipotleTweets    False  Mon Oct 30 15:00:02 +0000 2017
# 74       152  ChipotleTweets    False  Tue Oct 31 22:10:33 +0000 2017
# 75       153          115734     True  Tue Oct 31 22:01:03 +0000 2017
# 76       154  ChipotleTweets    False  Tue Oct 31 22:09:00 +0000 2017
# 77       155          115735     True  Tue Oct 31 22:00:46 +0000 2017
# 78       156          115735     True  Mon Oct 23 03:19:06 +0000 2017
# 79       158  ChipotleTweets    False  Tue Oct 31 22:08:00 +0000 2017
# 80       159          115736     True  Tue Oct 31 22:00:10 +0000 2017
# 81       160  ChipotleTweets    False  Tue Oct 31 22:06:55 +0000 2017
# 82       161          115737     True  Tue Oct 31 21:59:25 +0000 2017
# 83       162  ChipotleTweets    False  Tue Oct 31 19:51:00 +0000 2017
# 84       163          115737     True  Tue Oct 31 19:43:47 +0000 2017
# 85       164  ChipotleTweets    False  Tue Oct 31 22:03:32 +0000 2017
# 86       165          115738     True  Tue Oct 31 21:58:28 +0000 2017
# 87       166  ChipotleTweets    False  Tue Oct 31 22:02:25 +0000 2017
# 88       167          115739     True  Tue Oct 31 21:57:58 +0000 2017
# 89       168  ChipotleTweets    False  Tue Oct 31 22:01:39 +0000 2017
# 90       169          115740     True  Tue Oct 31 21:57:23 +0000 2017
# 91       170  ChipotleTweets    False  Tue Oct 31 22:01:00 +0000 2017
# 92       171          115741     True  Tue Oct 31 21:57:23 +0000 2017
# 93       172          115741     True  Tue Oct 31 21:57:08 +0000 2017
# 94       174  ChipotleTweets    False  Tue Oct 31 21:56:06 +0000 2017
# 95       175          115741     True  Tue Oct 31 21:54:13 +0000 2017
# 96       176  ChipotleTweets    False  Tue Oct 31 22:01:00 +0000 2017
# 97       177          115742     True  Tue Oct 31 21:57:19 +0000 2017
# 98       178  AskPlayStation    False  Tue Oct 31 22:14:49 +0000 2017
# 99       179          115744     True  Tue Oct 31 22:17:05 +0000 2017
#
#                                                  text  \
# 0   i understand. i would like to assist you. we w...
# 1                   and how do you propose we do that
# 2   i have sent several private messages and no on...
# 3   please send us a private message so that we ca...
# 4                                              i did.
# 5   can you please send us a private message, so t...
# 6                       is the worst customer service
# 7   this is saddening to hear. please shoot us a d...
# 8   you gonna magically change your connectivity f...
# 9   we understand your concerns and we had like fo...
# 10          since i signed up with you....since day 1
# 11  h there! we had definitely like to work with y...
# 12  y’all lie about your “great” connection. 5 bar...
# 13  please send me a private message so that i can...
# 14  whenever i contact customer support, they tell...
# 15                 what information is incorrect? ^jk
# 16  would you like me to email you a copy of one s...
# 17  our department is part of the corporate office...
# 18  i received this from your corporate office wou...
# 19                                  no thank you. ^jk
# 20  the correct way to do it is via an ocs account...
# 21  that is incorrect information i have the form ...
# 22  the information pertaining to the account assu...
# 23  actually that is a broken link you sent me and...
# 24  hello, my apologies for any frustrations or in...
# 25  yo , your customer service reps are super nice...
# 26  i apologize for the inconvenience. i will be g...
# 27  my picture on pretty much every day. why shoul...
# 28  help has arrived! we are sorry to see that you...
# 29      i finally got someone that helped me, thanks!
# ..                                                ...
# 70  no diet coke and a literal bone this boorito w...
# 71                    nope! still just the $3. -becky
# 72  if you get queso or quac on you are bowl, its ...
# 73  just stop by in costume 10/31 3pm-close. offic...
# 74  i mean, boorito is basically the adult version...
# 75  happy halloween! since i am too old to trick o...
# 76  i am so glad we could help. who did you work w...
# 77  thank you for resolving my issue so quickly!! ...
# 78  so frustrated with ordered dinner on saturday ...
# 79  all of our u.s. locations are participating! -...
# 80  btw giving out $3 burritos if you dress up for...
# 81  my apologies for that. just sent you a dm to h...
# 82                   tried, did not work. how rude :/
# 83                               give it a try. -tara
# 84  can i dress up as myself and still qualify for...
# 85  that is the best kind of trick-or-treating. al...
# 86  every year, my trick-or-treating routine is wa...
# 87  that is incredibly concerning. please provide ...
# 88     this is nasty. a used napkin in someone's food
# 89  bummer. i am so sorry. how far away is the clo...
# 90                 $3 burritos and i’m nowhere near a
# 91                                       noted -becky
# 92           also i got the onesie at target. so cozy
# 93  thanks becky! just feeling sorry for myself be...
# 94  you will not be alone – we will be there with ...
# 95  considering walking to in my llama onesie alon...
# 96  i love it! thanks so much for stopping by. -becky
# 97  name a better halloween duo #speedwaybrick #ut...
# 98  there is no info to share at the moment. feel ...
# 99                           can i get help already??
#
#                                     response_tweet_id  \
# 0                                                   2
# 1                                                 NaN
# 2                                                   1
# 3                                                   3
# 4                                                   4
# 5                                                 5,7
# 6                                              9,6,10
# 7                                                 NaN
# 8                                            11,13,14
# 9                                                  12
# 10                                                 15
# 11                                                 16
# 12                                                 17
# 13                                                NaN
# 14                                                 19
# 15                                              22,23
# 16                                                 25
# 17                                                 26
# 18                                                 27
# 19                                                NaN
# 20                                                NaN
# 21                                                 21
# 22                                                 24
# 23                                                 28
# 24                                                NaN
# 25                                                 30
# 26                                                NaN
# 27                                                 32
# 28                                                 35
# 29                                                 37
# ..                                                ...
# 70                                                 77
# 71                                                NaN
# 72                                                 79
# 73  80,82,83,84,85,86,87,88,89,90,91,92,93,94,95,9...
# 74                                                NaN
# 75                                                152
# 76                                                NaN
# 77                                                154
# 78                                            155,157
# 79                                                NaN
# 80                                                158
# 81                                                NaN
# 82                                                160
# 83                                                161
# 84                                                162
# 85                                                NaN
# 86                                                164
# 87                                                NaN
# 88                                                166
# 89                                                NaN
# 90                                                168
# 91                                                NaN
# 92                                                170
# 93                                            173,171
# 94                                                172
# 95                                                174
# 96                                                NaN
# 97                                                176
# 98                                                179
# 99                                                NaN
#
#     in_response_to_tweet_id   emoji
# 0                       3.0     NaN
# 1                       1.0     NaN
# 2                       4.0     NaN
# 3                       5.0     NaN
# 4                       6.0     NaN
# 5                       8.0     NaN
# 6                       NaN     NaN
# 7                      12.0     NaN
# 8                      15.0  [🤥, 💯]
# 9                      16.0     NaN
# 10                     17.0     NaN
# 11                     18.0     NaN
# 12                      NaN     NaN
# 13                     20.0     NaN
# 14                      NaN     NaN
# 15                     24.0     NaN
# 16                     21.0     NaN
# 17                     22.0     NaN
# 18                     25.0     NaN
# 19                     26.0     NaN
# 20                     21.0     NaN
# 21                     28.0     NaN
# 22                     29.0     NaN
# 23                      NaN     NaN
# 24                     31.0     NaN
# 25                      NaN     NaN
# 26                     33.0     NaN
# 27                      NaN     NaN
# 28                     36.0     NaN
# 29                     34.0     NaN
# ..                      ...     ...
# 70                      NaN     NaN
# 71                     80.0     NaN
# 72                     81.0     NaN
# 73                      NaN     NaN
# 74                    153.0     NaN
# 75                      NaN     [👻]
# 76                    155.0     NaN
# 77                    156.0     [☺]
# 78                      NaN     [😡]
# 79                    159.0     NaN
# 80                      NaN     [🎃]
# 81                    161.0     NaN
# 82                    162.0     NaN
# 83                    163.0     NaN
# 84                      NaN     NaN
# 85                    165.0     NaN
# 86                      NaN     NaN
# 87                    167.0     NaN
# 88                      NaN     NaN
# 89                    169.0     NaN
# 90                      NaN  [🤦, ♂]
# 91                    171.0     [😊]
# 92                    172.0     NaN
# 93                    174.0     NaN
# 94                    175.0     NaN
# 95                      NaN     [😭]
# 96                    177.0     NaN
# 97                      NaN     NaN
# 98                    180.0     NaN
# 99                    178.0     NaN
#
# [100 rows x 8 columns]

# %% [markdown]
# ### Retrieve sentiment score for emoji's
# ref:http://kt.ijs.si/data/Emoji_sentiment_ranking/

# %%
def build_dict(emoji_table, emoji_sentiment_dict):
    type_set = set()
    for i in range(emoji_table.shape[0]):
        code = emoji_table.loc[i, 'Python Code']
        try:
            key = chr(int(code[1:], 16))
            emoji_sentiment_dict[key] = emoji_table.loc[i, 'Sentiment score']
        except:
            type_set.add(emoji_table.loc[i, 'Unicode block'])
    return emoji_sentiment_dict

# %%
emoji_sentiment = pd.read_csv('./data/raw/emoji_nodingbat.csv')
emoji_other = pd.read_csv('./data/raw/emoji_other.csv')
emoji_sentiment_dict = {}

emoji_sentiment_dict = build_dict(emoji_sentiment, emoji_sentiment_dict)
emoji_sentiment_dict = build_dict(emoji_other, emoji_sentiment_dict)

# %%
def get_emoji_sentiment(emoji_list):
    score = 0
    if (type(emoji_list) != float):
        for emoji_item in emoji_list:
            if (emoji_item in emoji_sentiment_dict.keys()):
                score += emoji_sentiment_dict[emoji_item]
        if (score == 0):
            return np.NaN
        else:
            return score/len(emoji_list)
    else:
        return np.NaN

# %%
#twitter['emoji_score'] = twitter['emoji'].apply(lambda x:get_emoji_sentiment(x))
print ('Number of tweets with emoji score: ', twitter[~twitter['emoji_score'].isnull()].shape[0])
print ('Number of tweets with emoji but not score: ', twitter[twitter['emoji_score'].isnull() & (~twitter['emoji'].isnull())].shape[0])
# Out:
# Number of tweets with emoji score:  161402
# Number of tweets with emoji but not score:  33223

# %%
with open('./data/processed/tweets_step2_emoji_sentiment.pkl', 'wb')as picklefile:
    pickle.dump(twitter, picklefile)

# %%
with open('./data/processed/tweets_step2_emoji_sentiment.pkl', 'rb')as picklefile:
    twitter = pickle.load(picklefile)

# %% [markdown]
# ### Remove non-English tweets

# %%
# Retrieve elements that are printable in English context - This is a 
# combination of digits, letters, punctuation, and whitespace.
valid_content = set(string.printable)

# Include some common non-English punctuations
non_English_punctuation = ['‘', '’', 'é', '–','—','“','”','、','。','`','️', '£', '…', '$']

# Keep tweets with common non-English punctuations
[valid_content.add(x) for x in (non_English_punctuation)]
    
def isEnglish(tweet):
    invalid_index = [x not in valid_content for x in tweet]
    if (np.sum(invalid_index)==0):
        return True
    else:
        return False

## Removed 78k tweets with non-English characters
english_tweets = twitter.text.apply(lambda x:isEnglish(x))
tweets = twitter.loc[english_tweets, :]

# %%
# A quick tool to return non-English words
def non_English(words):
    print (list(compress(list(words), [x not in valid_content for x in words])))

# %% [markdown]
# ### Format the dates

# %%
# Format the dates
tweets['created_at'] = pd.to_datetime(tweets['created_at'], format='%a %b %d %H:%M:%S +0000 %Y')
# Out:
# /Users/songlin/anaconda2/envs/Python36/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
tweets['in_response_to_tweet_id'] = tweets['in_response_to_tweet_id'].fillna(-1)
tweets['in_response_to_tweet_id'] = tweets['in_response_to_tweet_id'].astype(int)
tweets['response_tweet_id'] = tweets['response_tweet_id'].fillna(-1)
# Out:
# /Users/songlin/anaconda2/envs/Python36/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/songlin/anaconda2/envs/Python36/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/songlin/anaconda2/envs/Python36/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
with open('./data/processed/tweets_step3_english.pkl', 'wb')as picklefile:
    pickle.dump(tweets, picklefile)

# %%
with open('./data/processed/tweets_step3_english.pkl', 'rb')as picklefile:
    tweets = pickle.load(picklefile)

# %% [markdown]
# ### Add custom_id and brand_id columns

# %%
tweets.shape
# Out:
# (2710745, 10)

# %%
# Add custom_id column
tweets = pd.merge(tweets,pd.DataFrame(tweets[['tweet_id', 'author_id']]),left_on='in_response_to_tweet_id', right_on='tweet_id', how='left')
tweets.loc[tweets['inbound'] == True, 'author_id_y'] = tweets.loc[tweets['inbound'] == True, 'author_id_x']
tweets['author_id_y'] = tweets['author_id_y'].fillna(-1)
tweets.drop('tweet_id_y', axis=1, inplace=True)
tweets.rename(columns={'author_id_y':'cust_id', 
                       'author_id_x':'author_id',
                      'tweet_id_x':'tweet_id'}, inplace=True)

# Drop the tweets without customer id, those are usually promotional tweets initiated by
# brands agent or customers not in the datase: Number of such tweets: 71255
tweets = tweets[~tweets['cust_id'].isnull()]

# %%
# Add brand_id column

# Carve out the first tweet id when there are multiples in response_tweet_id
tweets['processed_response_id'] = tweets['response_tweet_id'].apply(
    lambda x: x if (isinstance(x,int)) else x.split(',')[0])
tweets['processed_response_id'] = tweets['processed_response_id'].astype(int)

# Retrieve the author id of the responde tweet
tweets = pd.merge(tweets,pd.DataFrame(tweets[['tweet_id', 'author_id']]),
                  left_on='processed_response_id', 
                  right_on='tweet_id', 
                  how='left')

tweets.drop('tweet_id_y', axis=1, inplace=True)
tweets.rename(columns={'author_id_y':'brand_id', 
                       'author_id_x':'author_id',
                      'tweet_id_x':'tweet_id'}, inplace=True)

tweets = pd.merge(tweets,pd.DataFrame(tweets[['tweet_id', 'author_id']]),left_on='in_response_to_tweet_id', right_on='tweet_id', how='left')
tweets.loc[(tweets['inbound'] & (tweets['processed_response_id'] == -1)), 'brand_id'] = (
    tweets.loc[(tweets['inbound'] & (tweets['processed_response_id'] == -1)), 'author_id_y'])
tweets.rename(columns={'tweet_id_x':'tweet_id', 
                       'author_id_x':'author_id'}, inplace=True)

tweets.loc[tweets['inbound'] == False, 'brand_id'] = tweets.loc[tweets['inbound'] == False, 'author_id']
tweets.drop(['processed_response_id', 'tweet_id_y', 'author_id_y'], axis=1, inplace=True)

# could use some more logic to extract the account name in tweet text

# %%
# Tweets with no response is 3880
print (tweets[tweets['brand_id'].isnull() & (tweets['response_tweet_id'] == -1)].shape)

# Tweets with response outside the dataset is 42764
print (tweets[tweets['brand_id'].isnull() & (tweets['response_tweet_id'] != -1)].shape)

# Drop the tweets without brand_id
tweets = tweets[~tweets['brand_id'].isnull()]

# %%
with open('./data/processed/tweets_step4_brand_cust.pkl', 'wb')as picklefile:
    pickle.dump(tweets, picklefile)

# %%
with open('./data/processed/tweets_step4_brand_cust.pkl', 'rb')as picklefile:
    tweets = pickle.load(picklefile)

# %%
tweets.head()
# Out:
#    tweet_id   author_id  inbound          created_at  \
# 0         1  sprintcare    False 2017-10-31 22:10:47
# 1         2      115712     True 2017-10-31 22:11:45
# 2         3      115712     True 2017-10-31 22:08:27
# 3         4  sprintcare    False 2017-10-31 21:54:49
# 4         5      115712     True 2017-10-31 21:49:35
#
#                                                 text response_tweet_id  \
# 0  i understand. i would like to assist you. we w...                 2
# 1                  and how do you propose we do that                -1
# 2  i have sent several private messages and no on...                 1
# 3  please send us a private message so that we ca...                 3
# 4                                             i did.                 4
#
#    in_response_to_tweet_id emoji  emoji_score cust_id    brand_id
# 0                        3   NaN          NaN  115712  sprintcare
# 1                        1   NaN          NaN  115712  sprintcare
# 2                        4   NaN          NaN  115712  sprintcare
# 3                        5   NaN          NaN  115712  sprintcare
# 4                        6   NaN          NaN  115712  sprintcare

# %%
# Identify which tweets are in the same conversation (customer case)
tweets.sort_values(['cust_id', 'created_at'], inplace=True)
tweets.reset_index(inplace=True)

# Calculate the time difference (in seconds) bwetween a tweet and its previous tweet
tweets['time_diff'] = tweets['created_at'].diff()
tweets['time_diff'] = tweets['time_diff'].apply(lambda x:x.total_seconds())
tweets['time_diff'] = tweets['time_diff'].apply(lambda x: 0 if x <0 else x)
tweets['time_diff'] = tweets['time_diff'].fillna(0)

tweets['case_id'] = 0
tweets['time_diff'] = tweets['time_diff'].fillna(0)

# %% [markdown]
# ### Carve out the spotify support data

# %%
def analyze_brand(tweets, brand_cc_name):
    ## Subset tweets according to brand
    brand = tweets[tweets['brand_id'] == brand_cc_name]
    brand.reset_index(inplace=True)
    
    ## Assign unique caseid for each conversation (interchange of tweets)
    ## To avoid grouping different cases raised by the same customer at different time
    ## We set the max threshold between subsequent tweets in a conversation as 2 days
    caseid = 1
    brand.loc[0, 'case_id'] = caseid
    for row in range(1, brand.shape[0]):
        if (row%1000 == 0):
            print (row)
        if ((brand.loc[row, 'cust_id'] != brand.loc[row-1, 'cust_id']) |
            (brand.loc[row, 'time_diff'] > 3600*24*2)):
            caseid = caseid + 1
            brand.loc[row, 'time_diff'] = 0 # Set time between conversations as 0
            brand.loc[row, 'case_id'] = caseid
        else:
            brand.loc[row, 'case_id'] = caseid
    return brand

# %%
spotify = analyze_brand(tweets, 'SpotifyCares')
# Out:
# /Users/songlin/anaconda2/envs/Python36/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000

# %%
with open('./data/processed/spotify.pkl', 'wb')as picklefile:
    pickle.dump(spotify, picklefile)

# %%
with open('./data/processed/spotify.pkl', 'rb')as picklefile:
    spotify = pickle.load(picklefile)

# %% [markdown]
# ### Remove ticket without solution and solution without ticket

# %%
conv_count = spotify.groupby('case_id')['case_id'].count()
single_conv_index = conv_count[conv_count==1].index.tolist()
spotify['single_conv'] = spotify['case_id'].apply(
    lambda x: True if x in single_conv_index else False)

# Remove the conversations with only one tweet (424 ) 
spotify = spotify[~spotify['single_conv']]
spotify.drop('single_conv', axis=1, inplace=True)

spotify.drop(['level_0', 'index'], axis=1, inplace=True)

# %%
spotify.head()
# Out:
#    tweet_id     author_id  inbound          created_at  \
# 0   2747480          1084     True 2017-11-20 22:40:16
# 1   2747478  SpotifyCares    False 2017-11-20 22:46:58
# 2   2747479          1084     True 2017-11-20 22:55:34
# 3   2747481  SpotifyCares    False 2017-11-20 23:12:33
# 4   2606352         11543     True 2017-10-30 19:02:36
#
#                                                 text response_tweet_id  \
# 0  uh why is there a limit on how many songs i ca...           2747478
# 1  hey nick! there is currently a 10k limit in yo...           2747479
# 2  cool cool cool i think i am finally ready to s...           2747481
# 3  sorry to hear you feel that way. for now, you ...                -1
# 4  there used to be a useful feature in ios app t...           2606350
#
#    in_response_to_tweet_id emoji  emoji_score cust_id      brand_id  \
# 0                       -1   NaN          NaN    1084  SpotifyCares
# 1                  2747480   NaN          NaN    1084  SpotifyCares
# 2                  2747478   NaN          NaN    1084  SpotifyCares
# 3                  2747479   NaN          NaN    1084  SpotifyCares
# 4                       -1   NaN          NaN   11543  SpotifyCares
#
#    time_diff  case_id
# 0        0.0        1
# 1      402.0        1
# 2      516.0        1
# 3     1019.0        1
# 4        0.0        2

# %%
ticket = spotify[spotify['inbound'] == True]
solution = spotify[spotify['inbound'] == False]

# %%
# Remove ticket without solution or solution without ticket 
# conversations with tweets from only customer or customer agents

ticket = ticket.apply(
    lambda x: x if (x[12] in solution['case_id'].unique()) else None, axis = 1)
solution = solution.apply(
    lambda x: x if (x[12] in ticket['case_id'].unique()) else None, axis = 1)

# %%
#ticket.text.fillna('', inplace=True)
#solution.text.fillna('', inplace=True)
ticket_agg = ticket.groupby('case_id')['text'].agg(lambda x:' '.join(x))
solution_agg = solution.groupby('case_id')['text'].agg(lambda x:' '.join(x))

# %%
spotify = spotify.apply(
    lambda x: x if (x[10] in ticket['case_id'].unique()) else None, axis=1)

# %%
ticket['case_id'].unique().shape
# Out:
# (28788,)

# %% [markdown]
# ### Perform very basic sentiment analysis on last tweet from customer

# %%
cust_last_tweet = ticket.groupby('case_id')['text'].last().reset_index()

# %%
cust_last_tweet = ticket.groupby('case_id')[['text','emoji', 'emoji_score']].last().reset_index()

# %%
vdanalyzer = vaderSentiment.vaderSentiment.SentimentIntensityAnalyzer()
cust_last_tweet['vader_sentiment'] = cust_last_tweet['text'].apply(
        lambda x:vdanalyzer.polarity_scores(x)['compound'])

# %%
sentiment_analyzer = nltk.sentiment.vader.SentimentIntensityAnalyzer()
cust_last_tweet['ntlk_sentiment'] = cust_last_tweet['text'].apply(
        lambda x:sentiment_analyzer.polarity_scores(x)['compound'])

# %%
cust_last_tweet.to_csv('./data/processed/processed_last_tweet_sentiment.csv')

# %%
pd.set_option('display.max_colwidth', -1)
print (ticket[ticket['tweet_id'] == 2606351.0].text.astype(str))
# Out:
# 6    taking features away will only make it easier for users to go. i’ve been a premium user for 4+ years... don’t let me leave.
# Name: text, dtype: object

# %%
cust_last_tweet['sentiment'] = cust_last_tweet.apply(lambda
                        x:get_overall_sentiment_score(x), axis=1)

# %%
cust_last_tweet[['emoji_score', 'ntlk_sentiment']] = cust_last_tweet[['emoji_score', 'ntlk_sentiment']].astype(float)

# %%
def get_overall_sentiment_score(row):
    sentiment = ''
    if (not math.isnan(row[3])):
        if (row[3] >= 0.2):
            sentiment = 'POS'
        elif ((row[3] < 0.2) & (row[3] > -0.05)):
            sentiment = 'NEU'
        elif (row[3] <= -0.05):
            sentiment = 'NEG'
    elif (not math.isnan(row[5])):
        if (row[5] >= 0.2):
            sentiment = 'POS'
        elif ((row[5] < 0.2) & (row[5] > -0.05)):
            sentiment = 'NEU'
        elif (row[5] <= -0.05):
            sentiment = 'NEG'
    return sentiment

# %%
spotify.rename(columns ={'sentiment':'sentiment'}, inplace=True)

# %%
spotify = pd.merge(spotify, cust_last_tweet[['case_id', 'sentiment']],
                   left_on='case_id', right_on='case_id',
                   how='left')

# %%
spotify.drop('overall_sentiment_score', axis=1, inplace=True)

# %%
with open('./data/processed/tweets_step5_spotify_sentiment.pkl', 'wb')as picklefile:
    pickle.dump(spotify, picklefile)

# %%
with open('./data/processed/tweets_step5_spotify_sentiment.pkl', 'rb')as picklefile:
    spotify = pickle.load(picklefile)

# %% [markdown]
# ### Tweets preprocessing

# %%
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import string
import re

# %%
df_ticket = pd.DataFrame(ticket_agg)
df_ticket.reset_index(inplace=True)

# %%
df_solution = pd.DataFrame(solution_agg)
df_solution.reset_index(inplace=True)

# %%
df_ticket = pd.merge(df_ticket, cust_last_tweet[['case_id', 'sentiment']], left_on='case_id', right_on='case_id',
                   how='left')

# %%
def text_preprocess(text):
    tokens = word_tokenize(text)
    lemmatize = WordNetLemmatizer()
    clean_text = [lemmatize.lemmatize(token.lower().strip(), pos='a') for token in tokens]
    clean_text = [x for x in clean_text if x not in my_stop_words]
    return ' '.join(clean_text)

# %%
df_ticket['text'] = df_ticket.text.apply(lambda x:text_preprocess(x))

# %% [markdown]
# ### Perform word embedding

# %%
custom_stopwords = ['http', 'https', 'spotify', 'help', 'hi', 'spotifycares']
my_stop_words = (text.ENGLISH_STOP_WORDS.union(custom_stopwords)
                 .union(string.punctuation))

# %%
tfidf_vectorizer = TfidfVectorizer(ngram_range=(1, 2),  
                                   stop_words=my_stop_words, 
                                   token_pattern="\\b[a-z][a-z]+\\b",
                                   lowercase=True,
                                   max_df = 0.6)
tfidf_data = tfidf_vectorizer.fit_transform(list(df_ticket.text))

# %%
class RecommendationEngine:
    def __init__(self, vectorizer, n_components, reducer):
        self.vectorizer = vectorizer
        self.n_dim = n_components
        self.reducer = reducer(n_components)
        
    def fit(self, text):
        self.vector_data = self.vectorizer.fit_transform(text)
        self.topic_data = self.reducer.fit_transform(self.vector_data)
        self.texts = text
        
    def recommend(self, article, num_to_return):
        article_vectorized = self.vectorizer.transform([article])
        article_topic_vector = self.reducer.transform(article_vectorized)
        nn = NearestNeighbors(n_neighbors=num_to_return, metric='cosine', algorithm='brute')
        nn.fit(self.topic_data)
        results = nn.kneighbors(article_topic_vector)
        
        result_texts = [self.texts[i] for i in results[1][0]]
        
        return result_texts

# %%
n_comp = 300
lsa_tfidf = TruncatedSVD(n_components=n_comp)
lsa_tfidf_data = lsa_tfidf.fit_transform(tfidf_data)

# %%
def display_topics(model, feature_names, no_top_words, topic_names=None):
    for ix, topic in enumerate(model.components_):
        if not topic_names or not topic_names[ix]:
            print("\nTopic ", ix)
        else:
            print("\nTopic: '",topic_names[ix],"'")
        print(", ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))

# %%
display_topics(lsa_tfidf,tfidf_vectorizer.get_feature_names(),10)
# Out:
# Topic  0
# account, premium, family, student, just, need, email, premium account, app, thanks
#
# Topic  1
# account, premium, student, premium account, charged, email, family, hulu, facebook, hacked
#
# Topic  2
# dm, sent, sent dm, need, check, check dm, thanks, account, email, thank
#
# Topic  3
# premium, dm, student, charged, discount, family, sent, student discount, month, sent dm
#
# Topic  4
# app, iphone, update, student, charged, dm, app iphone, update app, discount, student discount
#
# Topic  5
# need, reputation, student, charged, thank, discount, album, student discount, available, hulu
#
# Topic  6
# need, family, iphone, app, update, premium, plan, family plan, need account, app iphone
#
# Topic  7
# reputation, iphone, thank, update, app, available, reputation available, app iphone, update app, family
#
# Topic  8
# thank, need, family, thank thank, dm thank, iphone, plan, account thank, family plan, thank guys
#
# Topic  9
# thanks, student, family, plan, email, discount, family plan, student discount, charged, update
#
# Topic  10
# thanks, premium, premium account, thank, free, need, working, paid, cancel, paid premium
#
# Topic  11
# email, password, address, email address, premium, reset, changed, log, reset password, just
#
# Topic  12
# apple, app, music, watch, reputation, apple watch, watch app, account, apple music, student
#
# Topic  13
# album, new, apple, watch, new album, apple watch, app, music, watch app, apple music
#
# Topic  14
# having, working, log, issues, work, payment, having issues, does, album, hulu
#
# Topic  15
# charged, twice, charged twice, month, free, just, got, log, got charged, account
#
# Topic  16
# payment, music, card, having, update, hey, issues, credit, credit card, having issues
#
# Topic  17
# having, songs, issues, having issues, app, charged, trouble, having trouble, email, album
#
# Topic  18
# log, facebook, hey, playlist, app, songs, log account, cancel, card, apple watch
#
# Topic  19
# hey, working, available, does, song, work, guys, india, card, account
#
# Topic  20
# fix, hey, music, log, guys, na, gon na, gon, hulu, india
#
# Topic  21
# working, fix, card, payment, songs, credit, credit card, isn, pls, isn working
#
# Topic  22
# does, hey, fix, work, does work, new, reputation, music, guys, premium
#
# Topic  23
# working, song, playlist, music, isn, play, apple, charged, isn working, add
#
# Topic  24
# fix, song, available, playlist, pls, play, card, premium, charged, music
#
# Topic  25
# available, working, india, songs, music, na, available india, gon, gon na, log
#
# Topic  26
# hey, music, app, card, songs, downloaded, phone, android, premium account, getting
#
# Topic  27
# free, says, songs, hey, available, trial, ad, fix, does, free trial
#
# Topic  28
# songs, apple, password, watch, apple watch, just, update, getting, fix, reset
#
# Topic  29
# na, gon, gon na, app, wan na, wan, playlist, add, password, music
#
# Topic  30
# log, song, play, hey, songs, subscription, na, card, check, cancel
#
# Topic  31
# log, playlist, hacked, sent, card, sent dm, got, account hacked, log account, music
#
# Topic  32
# hulu, service, like, pay, customer, hacked, customer service, guys, really, account hacked
#
# Topic  33
# hulu, sent, subscription, cancel, sent dm, playlist, card, music, hey, access
#
# Topic  34
# check, hulu, just, check dm, got, playlist, india, pls, payment, trying
#
# Topic  35
# add, bring, update, sent, app, web, player, payment, web player, sent dm
#
# Topic  36
# hulu, change, log, like, hulu account, twice, username, song, working, charged twice
#
# Topic  37
# web, player, web player, pay, like, facebook, hulu, card, play, login
#
# Topic  38
# add, card, want, just, credit, credit card, iphone, pay, password, reset
#
# Topic  39
# new, facebook, add, guys, india, artist, problem, login, issue, phone
#
# Topic  40
# service, customer, customer service, facebook, pay, want, update, login, month, app
#
# Topic  41
# india, change, new, bring, launch, come, plan, password, want, play
#
# Topic  42
# change, add, service, customer, username, customer service, available, support, change username, iphone
#
# Topic  43
# new, available, playlists, web, player, web player, password, reset, song, make
#
# Topic  44
# bring, going, pls, just, preview, card, touch, touch preview, like, lyrics
#
# Topic  45
# like, india, cancel, album, play, add, launch, come, card, know
#
# Topic  46
# going, artist, guys, hello, does, app, card, just, change, check
#
# Topic  47
# pay, add, going, month, payment, like, pls, issue, version, pay premium
#
# Topic  48
# hello, bring, like, want, problem, hey, does, address, play, really
#
# Topic  49
# hello, artist, pay, just, page, hacked, pls, month, change, check
#
# Topic  50
# problem, pay, login, add, update, password, song, like, just, got
#
# Topic  51
# login, got, hacked, facebook, hello, going, account hacked, want, like, plan
#
# Topic  52
# problem, pls, playlists, discover, weekly, change, discover weekly, listen, add, going
#
# Topic  53
# discover, weekly, discover weekly, hello, playlists, song, did, work, india, facebook
#
# Topic  54
# guys, getting, change, error, does, username, getting error, got, message, really
#
# Topic  55
# playlists, guys, play, does, plan, just, playlist, album, albums, month
#
# Topic  56
# did, getting, playlists, really, problem, time, work, month, song, playlist
#
# Topic  57
# pls, plan, did, going, family plan, phone, update, cancel, artist, work
#
# Topic  58
# issue, got, does, update, android, download, getting, phone, player, time
#
# Topic  59
# playlists, got, pay, play, subscription, love, make, time, really, family account
#
# Topic  60
# issue, pls, problem, app, work, login, month, support, check, sent
#
# Topic  61
# listen, sent, check, says, subscription, guys, update, family, pls, sent dm
#
# Topic  62
# check, sent, sent dm, check dm, got, dms, check dms, payment, issues, iphone
#
# Topic  63
# listen, payment, plan, really, support, iphone, family plan, love, song, ios
#
# Topic  64
# listen, work, month, plan, add, update, love, family plan, cancel, premium account
#
# Topic  65
# really, subscription, plan, says, issue, family plan, getting, charged, pay, update
#
# Topic  66
# really, time, months, month, says, love, sign, play, let, download
#
# Topic  67
# really, ads, ad, work, playing, love, stop, way, pls, facebook
#
# Topic  68
# login, let, issues, really, listen, play, time, did, having issues, love
#
# Topic  69
# login, work, want, really, log, velvet, month, song, perfect, perfect velvet
#
# Topic  70
# let, really, cancel, trying, know, sign, trouble, having trouble, won, keeps
#
# Topic  71
# velvet, perfect, perfect velvet, time, cancel, red velvet, red, pay, twice, charged
#
# Topic  72
# let, know, subscription, velvet, won, perfect, perfect velvet, don, won let, issues
#
# Topic  73
# month, listen, velvet, did, play, perfect, perfect velvet, care, really, login
#
# Topic  74
# access, really, phone, listen, facebook, work, playlist, support, discount, play
#
# Topic  75
# trouble, having trouble, know, love, phone, support, payment, getting, play, contact
#
# Topic  76
# love, code, presale, version, says, presale code, month, know, access, using
#
# Topic  77
# months, login, day, version, charged, trial, code, waiting, albums, signed
#
# Topic  78
# albums, love, code, phone, trying, presale, fuck, ads, stop, playing
#
# Topic  79
# access, code, says, playing, presale, months, phone, presale code, stop, long
#
# Topic  80
# albums, says, access, ios, version, know, got, fuck, trouble, service
#
# Topic  81
# code, presale, time, presale code, subscription, really, twice, month, premium account, charged twice
#
# Topic  82
# way, support, albums, ads, ad, android, year, contact, says, know
#
# Topic  83
# make, way, android, albums, let, fuck, know, support, username, good
#
# Topic  84
# twice, charged twice, year, access, months, paid, discount, student discount, paid premium, code
#
# Topic  85
# fuck, wtf, support, wrong, taylor, code, shit, swift, taylor swift, android
#
# Topic  86
# way, fuck, care, know, year, isn, time, day, twice, wan na
#
# Topic  87
# months, taylor, taylor swift, swift, know, twice, charged twice, wrong, use, velvet
#
# Topic  88
# wtf, months, facebook, know, code, ad, wrong, cancel, student, playlists
#
# Topic  89
# way, wtf, sign, paid, username, paid premium, money, charged, use, discount
#
# Topic  90
# playing, stop, discount, let, albums, student discount, username, paid, hulu, trial
#
# Topic  91
# year, wtf, taylor, swift, taylor swift, know, waiting, phone, make, isn
#
# Topic  92
# fuck, cancel, ad, charged, hulu, paid, let, payment, times, phone
#
# Topic  93
# care, let, isn, way, months, taylor, won, swift, taylor swift, won let
#
# Topic  94
# wrong, way, waiting, year, went, went wrong, use, oops, oops went, trying
#
# Topic  95
# care, use, ve, waiting, trying, isn, explain, tried, times, ads
#
# Topic  96
# sign, premium account, wrong, isn, tried, waiting, try, subscription, reply, let
#
# Topic  97
# username, wrong, sign, android, care, access, trying, paid, code, know
#
# Topic  98
# use, come, username, sign, android, payment, discount, getting, im, artist
#
# Topic  99
# username, waiting, im, come, using, payment, change username, isn, sign, getting
#
# Topic  100
# waiting, paid, come, paid premium, reply, playing, fuck, contact, sign, use
#
# Topic  101
# come, isn, address, contact, email address, isn working, trying, discount, year, using
#
# Topic  102
# username, use, tried, avail, feature, ve, wan, wan na, come, student
#
# Topic  103
# waiting, discount, contact, premium account, student discount, trying, hulu, ios, reply, wtf
#
# Topic  104
# address, waiting, wan na, wan, email address, contact, username, try, money, bring
#
# Topic  105
# address, waiting, im, phone, sign, albums, use, email address, feature, paid
#
# Topic  106
# isn, isn working, bring, did, using, trying, ve, android, know, waiting
#
# Topic  107
# feature, wan na, wan, keeps, preview, download, ios, shuffle, touch, touch preview
#
# Topic  108
# contact, using, premium account, come, wan na, wan, care, bring, year, download
#
# Topic  109
# money, wan na, wan, android, good, tried, come, getting, email, change
#
# Topic  110
# reply, reply dm, using, money, year, thanks reply, message, phone, im, check
#
# Topic  111
# contact, strange, things, mode, strange things, things mode, money, using, im, explain
#
# Topic  112
# premium account, strange, things, strange things, mode, things mode, trying, good, come, avail
#
# Topic  113
# paying, keeps, im, money, desktop, free, use, saying, playing, lyrics
#
# Topic  114
# android, avail, keeps, im, downloaded, iphone, app iphone, contact, tried, care
#
# Topic  115
# avail, contact, good, shuffle, reply, im, amp, wrong, reply dm, ios
#
# Topic  116
# avail, keeps, waiting, saying, desktop, promo, email, error, message, lyrics
#
# Topic  117
# avail, playing, premium account, download, trying, feature, promo, free, email, charged
#
# Topic  118
# good, im, ads, message, paid, day, email, app iphone, feature, error
#
# Topic  119
# good, premium account, money, long, avail, contact, downloaded, keeps, paid, im
#
# Topic  120
# long, good, playing, contact, iphone, tried, download, upgrade, changed, app iphone
#
# Topic  121
# im, downloaded, tried, play, isn, upgrade, days, version, wrong, students
#
# Topic  122
# good, using, downloaded, preview, feature, waiting, access, lemonade, touch, play
#
# Topic  123
# lyrics, desktop, downloaded, shit, getting, option, feature, tried, iphone, coming
#
# Topic  124
# ok, shuffle, shit, good, long, days, downloaded, ad, using, ago
#
# Topic  125
# ve, don, good, message, long, lyrics, error, ads, avail, downloaded
#
# Topic  126
# amp, ok, coming, soon, money, changed, ok thanks, lyrics, ve, password
#
# Topic  127
# paying, ok, amp, explain, students, long, shit, school, email, paying premium
#
# Topic  128
# ok, day, ve, students, changed, explain, ok thanks, getting, paid, school
#
# Topic  129
# don, shit, download, getting, explain, students, keeps, ok, think, limit
#
# Topic  130
# explain, version, shit, desktop, shuffle, days, windows, ok, app iphone, know
#
# Topic  131
# shit, day, changed, lemonade, ad, paying, logged, paid, upgrade, fix shit
#
# Topic  132
# students, days, school, high, high school, ad, explain, school students, playing, don
#
# Topic  133
# students, stop, changed, school, high, high school, downloaded, long, shuffle, months
#
# Topic  134
# lyrics, ads, days, ios, gone, paying, shit, info, option, today
#
# Topic  135
# explain, ve, lyrics, try, token, csrf token, invalid, csrf, token invalid, downloaded
#
# Topic  136
# shit, coming, ve, soon, students, problems, lemonade, having problems, school, ads
#
# Topic  137
# explain, coming, stop, soon, don, gone, good, upgrade, password, message
#
# Topic  138
# today, coming, stop, soon, gone, lemonade, logged, ad, release, africa
#
# Topic  139
# lemonade, app iphone, update app, lemonade album, soon, don, version, coming, playing, ads
#
# Topic  140
# update app, app iphone, version, stop, day, support, keeps, ad, late, lyrics
#
# Topic  141
# lemonade, stop, keeps, ve, link, gone, today, message, artist, able
#
# Topic  142
# problems, having problems, today, having, days, stop, gone, ago, times, happened
#
# Topic  143
# today, playing, gone, ads, logged, yo, app iphone, update app, version, happened
#
# Topic  144
# option, gone, page, logged, ve, country, upgrade, able, link, signed
#
# Topic  145
# logged, artist, gone, times, offline, shit, trying, day, saved, fb
#
# Topic  146
# signed, page, need account, today, signed premium, offline, just signed, members, lyrics, error
#
# Topic  147
# yo, page, able, stop, lyrics, days, logged, gone, ago, don
#
# Topic  148
# fixed, times, need account, artists, release, buy, page, day, days, sure
#
# Topic  149
# yo, option, able, changed, today, need account, downloaded, buy, fixed, remove
#
# Topic  150
# fixed, option, yo, update iphone, password, tried, preview, ve, need account, anymore
#
# Topic  151
# yo, version, times, update iphone, signed, country, deleted, app, artists, page
#
# Topic  152
# yo, fixed, offline, times, soon, screen, ios, switch, right, try
#
# Topic  153
# times, able, yo, need account, signed, charged times, upgrade, option, ve, change
#
# Topic  154
# release, fixed, question, gone, logged, asap, radar, release radar, yo, artists
#
# Topic  155
# fixed, able, asap, delete, signed, saved, right, deleted, changed, accounts
#
# Topic  156
# need account, upgrade, sure, offline, fixed, right, yo, link, able, tried
#
# Topic  157
# question, times, gone, signed, need account, answer, changed, think, accounts, possible
#
# Topic  158
# question, need account, offline, delete, option, answer, yo, dms, saved, tried
#
# Topic  159
# question, asap, answer, logged, dms, anymore, check dms, link, limit, country
#
# Topic  160
# accounts, fixed, listening, logged, think, albums, page, link, late, update iphone
#
# Topic  161
# link, offline, gone, asap, website, updated, page, changed, info, buy
#
# Topic  162
# listening, asap, daily, think, sure, happened, gone, mix, coming, mixes
#
# Topic  163
# release, thing, right, sure, touch, preview, radar, release radar, change, touch preview
#
# Topic  164
# gone, dms, connect, late, check dms, country, offline, able, try, screen
#
# Topic  165
# updated, switch, buy, message, members, apple music, country, wrong, okay, family members
#
# Topic  166
# question, coming, check dm, screen, africa, south, south africa, delete, updated, apple music
#
# Topic  167
# buy, members, buy premium, offline, question, family members, ios, gift, happened, upgrade
#
# Topic  168
# right, listening, check dm, question, soon, mobile, watch, don, great, apple watch
#
# Topic  169
# delete, need account, asap, website, thing, country, members, message, listening, gone
#
# Topic  170
# delete, buy, try, link, logged, website, buy premium, number, artists, info
#
# Topic  171
# think, great, delete, asap, okay, africa, south, south africa, release, late
#
# Topic  172
# right, accounts, dms, need account, delete, screen, check dms, logged, buy, desktop
#
# Topic  173
# asap, need account, late, daily, members, try, family members, link, switch, check dm
#
# Topic  174
# updated, daily, country, preview, happened, touch, question, desktop, info, touch preview
#
# Topic  175
# website, info, right, daily, refund, think, asap, need account, password, search
#
# Topic  176
# website, right, members, late, family members, pesos, feature, dms, load, coming
#
# Topic  177
# right, think, refund, limit, library, listening, artists, saved, cancelled, updated
#
# Topic  178
# anymore, screen, okay, pesos, website, try, accounts, doesn, buy, tell
#
# Topic  179
# cancelled, refund, daily, fb, happened, okay, deleted, old, ago, mixes
#
# Topic  180
# pesos, think, daily, delete, happened, member, number, update iphone, mix, mixes
#
# Topic  181
# artists, refund, cancelled, error, great, link, updated, anymore, right, pesos
#
# Topic  182
# anymore, won, great, remove, connect, yes, members, saved, screen, family members
#
# Topic  183
# okay, message, refund, pesos, try, won, updated, send, cancelled, thing
#
# Topic  184
# pesos, listening, buy, thing, great, updated, buy premium, website, possible, saved
#
# Topic  185
# sure, won, deleted, listening, error, website, delete, accounts, coming, pretty
#
# Topic  186
# happened, africa, south, late, south africa, error, launch, possible, won, right
#
# Topic  187
# remove, updated, refund, sure, number, limit, okay, won, mobile, saved
#
# Topic  188
# okay, coming, mobile, connect, member, won, fb, website, reason, right
#
# Topic  189
# happened, late, dear, mobile, updated, pesos, screen, let, christmas, device
#
# Topic  190
# pesos, info, tell, fb, right, old, years, bad, number, day
#
# Topic  191
# happened, number, won, accounts, thing, great, phone number, offer, okay, mobile
#
# Topic  192
# thing, bad, okay, remove, people, search, years, sort, ago, week
#
# Topic  193
# thing, annoying, number, think, anymore, won, search, mobile, yes, fb
#
# Topic  194
# anymore, okay, let, thing, website, late, yes, factor, important like, supporttwofactorauth
#
# Topic  195
# late, member, message, family member, cool, old, used, send, card, eligible
#
# Topic  196
# happened, important, factor, security, factor auth, supporttwofactorauth, security important, important like, supported factor, auth supporttwofactorauth
#
# Topic  197
# info, late, security, factor, supporttwofactorauth, auth supporttwofactorauth, like supported, security important, important like, supported factor
#
# Topic  198
# tell, mobile, updated, dear, deleted, try, africa, bad, south, south africa
#
# Topic  199
# limit, possible, people, years, deal, ago, sure, great, credit, rap
#
# Topic  200
# tell, fb, late, rap, won, thing, desktop, website, acct, buy
#
# Topic  201
# tell, possible, people, trial, years, annoying, yes, eligible, cool, free trial
#
# Topic  202
# deleted, connect, possible, rap, card, update iphone, pesos, thing, acid, acid rap
#
# Topic  203
# rap, acid rap, acid, dear, sort, feature, added, people, answer, trial
#
# Topic  204
# christmas, cool, rap, charge, deal, dear, connect, refund, acid, acid rap
#
# Topic  205
# sleep, sleep timer, timer, member, rap, info, acid rap, acid, family member, accounts
#
# Topic  206
# saved, saved songs, sure, download, connect, bad, disappeared, anymore, fb, sleep
#
# Topic  207
# dear, family premium, week, great, ago, student account, trial, years, load, join
#
# Topic  208
# possible, works, answer, happened, anymore, refund, remove, old, rap, switch
#
# Topic  209
# sort, yes, refund, eligible, people, possible, dear, sleep, sure, sleep timer
#
# Topic  210
# deal, mobile, late, won, week, sort, old, answer, eligible, join
#
# Topic  211
# needs, yes, cancelled, deal, works, number, week, rap, annoying, saved
#
# Topic  212
# people, old, yes, saying, mean, bad, info, student account, does mean, family premium
#
# Topic  213
# sort, deal, offer, eligible, info, connect, works, member, tell, reset
#
# Topic  214
# christmas, sort, old, limit, mean, possible, logging, doesn, week, does mean
#
# Topic  215
# christmas, remove, cool, people, search, reset, fb, cancelled, reset password, happened
#
# Topic  216
# dear, annoying, anymore, sort, button, deal, user, needs, invite, credit
#
# Topic  217
# needs, added, sort, mobile, button, switch, old, mean, library, phone
#
# Topic  218
# annoying, yes, join, years, refund, old, update iphone, ago, bad, asap
#
# Topic  219
# mean, does mean, week, join, annoying, possible, doesn, search, charge, answer
#
# Topic  220
# charge, logging, dear, price, fb, user, used, answer, acct, works
#
# Topic  221
# charge, week, eligible, works, cool, doesn, button, old, sort, number
#
# Topic  222
# answer, saya, charge, ya, invite, yes, old, cool, members, bisa
#
# Topic  223
# eligible, christmas, promo, bad, offer, thing, reset, anymore, yes, mean
#
# Topic  224
# annoying, sort, christmas, wish, great, mean, charge, explicit, block, does mean
#
# Topic  225
# refund, yes, christmas, answer, dear, old, listening, set, deal, sure
#
# Topic  226
# christmas, reason, eligible, answer, sort, needs, cancelled, library, bad, people
#
# Topic  227
# dear, premium family, week, button, mean, annoying, limit, iphone update, load, member
#
# Topic  228
# family premium, refund, people, logging, respond, saya, doesn, ya, cool, super
#
# Topic  229
# cancelled, people, device, old, dear, annoying, offer, week, membership, different
#
# Topic  230
# cool, answer, needs, eligible, annoying, added, saying, details, screen, refund
#
# Topic  231
# load, reason, user, send, button, mean, old, student premium, tracks, subscribe
#
# Topic  232
# button, added, invite, used, fine, doesn, works, answer, recently, ago
#
# Topic  233
# added, premium family, profile, update iphone, number, dear, happening, price, set, student account
#
# Topic  234
# cool, doesn, cancelled, load, price, explicit, offer, used, sort, premium family
#
# Topic  235
# added, send, family premium, dear, share, customer, mobile, talk, doesn, price
#
# Topic  236
# iphone update, profile, load, user, send, trial, doesn, annoying, week, needs
#
# Topic  237
# cool, new album, family premium, happening, wish, update iphone, library, bad, block, eligible
#
# Topic  238
# added, iphone update, family premium, bad, student premium, library, charge, screen, switch, yes
#
# Topic  239
# user, details, profile, button, windows, week, student account, connect, payment details, logging
#
# Topic  240
# iphone update, wish, student account, mean, does mean, instead, screen, premium family, join, block
#
# Topic  241
# launch, new album, launch india, tracks, plz, eligible, profile, family premium, iphone update, invite
#
# Topic  242
# bad, reason, eligible, dear, idea, devices, family account, respond, trial, charging
#
# Topic  243
# launch, windows, student account, send, different, library, talk, launch india, refund, fb
#
# Topic  244
# details, offer, new album, doesn, payment details, iphone update, annoying, switch, added, thx
#
# Topic  245
# offer, reason, switch, week, family account, button, different, monthly, pesos, member
#
# Topic  246
# family premium, wait, used, load, devices, eligible, super, response, removed, super slimey
#
# Topic  247
# recently, played, bad, week, happening, doing, set, student premium, talk, send
#
# Topic  248
# share, user, super, wish, old, pixel, slimey, super slimey, switch, load
#
# Topic  249
# plz, launch, button, share, new album, launch india, respond, idea, talk, played
#
# Topic  250
# plz, lol, wait, price, real, user, details, instead, talk, accept
#
# Topic  251
# windows, verified, price, respond, wait, offer, logging, switch, bad, button
#
# Topic  252
# plz, device, wait, price, works, ur, instead, switch, added, profile
#
# Topic  253
# windows, reason, super, lol, super slimey, slimey, doing, set, apple music, messaged
#
# Topic  254
# doing, instead, price, response, wish, lol, charging, different, iphone update, look
#
# Topic  255
# verified, details, hope, tracks, keeps, eligible, suggested, went, windows, removed
#
# Topic  256
# thx, plz, taken, week, explicit, worked, super, tracks, library, windows
#
# Topic  257
# membership, instead, verified, years, wait, premium membership, lol, profile, thx, doing
#
# Topic  258
# verified, thx, bad, dont, family account, wish, devices, bought, time capsule, capsule
#
# Topic  259
# talk, ur, super, idea, best, tracks, dont, instead, need talk, slimey
#
# Topic  260
# windows, device, premium family, lol, wait, happening, user, tracks, switch, talk
#
# Topic  261
# talk, need talk, price, real, upgraded, devices, doing, membership, profile, sierra
#
# Topic  262
# verified, different, idea, lol, reason, eligible, new album, instead, lost, set
#
# Topic  263
# plz, wish, respond, happening, windows, mixtapes, added, join, response, happens
#
# Topic  264
# instead, set, uk, plz, best, linked, user, hope, isnt, devices
#
# Topic  265
# respond, lol, wait, used, talk, track, customers, library, promo, charging
#
# Topic  266
# membership, instead, unable, family account, customers, used, ur, talk, device, premium membership
#
# Topic  267
# lol, respond, instead, verified, launch, upgraded, happening, actually, device, created
#
# Topic  268
# happening, lol, removed, real, library, paypal, best, ur, charging, messaged
#
# Topic  269
# plz, lol, response, devices, customers, random, different, membership, monthly, student account
#
# Topic  270
# response, verified, charging, happens, messaged, library, idea, account hacked, old, hope
#
# Topic  271
# ur, verified, taken, uk, lol, old, new album, worked, added, button
#
# Topic  272
# respond, years, upgraded, acct, explicit, taken, best, customer, happening, price
#
# Topic  273
# join, doing, premium family, idea, thx, promo, device, wrong, bought, look
#
# Topic  274
# linked, thx, paypal, hope, customer, account linked, linked account, charging, promo, join
#
# Topic  275
# uk, doing, dont, explicit, lol, showing, online, streaming, verified, pretty
#
# Topic  276
# real, hear, messaged, customers, paypal, hope, oh, cheers, look, instead
#
# Topic  277
# best, looks, upgraded, oh, looks like, membership, isnt, respond, hear, response
#
# Topic  278
# removed, thx, devices, uk, wait, happen, upgraded, verified, response, open
#
# Topic  279
# look, used, dont, open, fucking, instead, premium subscription, lost, eligible, linked
#
# Topic  280
# paypal, messaged, idea, promo, removed, ll, wifi, happens, track, profile
#
# Topic  281
# instead, charging, log account, code, wifi, galaxy, student premium, removed, real, information
#
# Topic  282
# real, taken, uk, price, wait, response, streaming, paypal, linked, happen
#
# Topic  283
# real, ur, customers, upgraded, set, linked, information, tho, looks, customer
#
# Topic  284
# oh, real, removed, messaged, fucking, premium family, information, pretty, podcasts, online
#
# Topic  285
# dont, thx, removed, years, taken, fucking, ll, monthly, response, time capsule
#
# Topic  286
# lol, follow, isnt, pretty, actually, used, ll, cheers, looks, loading
#
# Topic  287
# messaged, taken, mixtapes, queue, computer, charging, customers, lost, dont, used
#
# Topic  288
# cc, loading, customers, happens, unable, account hacked, pretty, hear, price, open
#
# Topic  289
# messaged, best, devices, reputation available, instead, windows, isnt, hear, received, taken
#
# Topic  290
# ll, podcast, hope, acct, suggested, appreciate, uk, received, sent dm, respond
#
# Topic  291
# hope, messaged, service, acct, look, multiple, idea, price, devices, ad
#
# Topic  292
# real, reputation available, charged premium, offer, acct, taken, list, verified, open, multiple
#
# Topic  293
# promo, dont, isnt, thought, happens, happen, missing, hacked account, sucks, weeks
#
# Topic  294
# look, information, idea, thx, morning, disappeared, suggested, lost, unable, showing
#
# Topic  295
# cheers, response, missing, broken, wondering, hope, friends, podcast, thought, bank
#
# Topic  296
# unable, forgot, devices, happen, ur, idea, having, thought, alvarez, removed
#
# Topic  297
# happen, cheers, block, hope, open, ll, account hacked, worked, soundtrack, loading
#
# Topic  298
# cc, cheers, removed, reputation available, offer, morning, oh, premium subscription, weeks, instead
#
# Topic  299
# ll, said, tf, removed, look, create, queue, oh, radio, block

# %%
def get_recommendations(first_article, model, vectorizer, training_vectors):
    '''
    first_article: (string) An article that we want to use to find similar articles
    model: (a fit dimensionality reducer) Projects vectorized words onto a subspace 
           (uses NMF or SVD/LSA typically)
    vectorizer: Vectorizes first_article 
    training_vectors: (numpy array shape) a (num_docs in training) x (NMF/SVD/LSA) dimensional array.
                      Used to train NearestNeighbors model
    '''
    new_vec = model.transform(
        vectorizer.transform([first_article]))
    nn = NearestNeighbors(n_neighbors=3, metric='cosine', algorithm='brute')
    nn.fit(training_vectors)
    results = nn.kneighbors(new_vec)
    return results[1][0] # 1st row is the score

# %%
ticket.head()
# Out:
#           tweet_id author_id inbound           created_at  \
# case_id
# 1.0      2747480.0  1084      True    2017-11-20 22:40:16
# 1.0      2747479.0  1084      True    2017-11-20 22:55:34
# 2.0      2606352.0  11543     True    2017-10-30 19:02:36
# 2.0      2606351.0  11543     True    2017-10-30 21:34:32
# 3.0      855.0      115887    True    2017-10-31 19:10:51
#
#                                                                                                                                 text  \
# case_id
# 1.0      uh why is there a limit on how many songs i can "save" — how am i supposed to keep track of the albums i like?
# 1.0      cool cool cool i think i am finally ready to switch to apple music
# 2.0      there used to be a useful feature in ios app that allowed user to hear sample of song by touch+hold on song. gone?
# 2.0      taking features away will only make it easier for users to go. i’ve been a premium user for 4+ years... don’t let me leave.
# 3.0      i’m pissed my shuffle and repeat button just don’t fucking work and i’m getting frustrated
#
#         response_tweet_id  in_response_to_tweet_id emoji  emoji_score cust_id  \
# case_id
# 1.0      2747478          -1.0                      NaN  NaN           1084
# 1.0      2747481           2747478.0                NaN  NaN           1084
# 2.0      2606350          -1.0                      NaN  NaN           11543
# 2.0      2606353           2606350.0                NaN  NaN           11543
# 3.0      854              -1.0                      NaN  NaN           115887
#
#              brand_id  time_diff  case_id
# case_id
# 1.0      SpotifyCares  0.0        1.0
# 1.0      SpotifyCares  516.0      1.0
# 2.0      SpotifyCares  0.0        2.0
# 2.0      SpotifyCares  2293.0     2.0
# 3.0      SpotifyCares  0.0        3.0

# %%
df_ticket.text[0]
# Out:
# "uh limit songs `` save '' — supposed track albums like cool cool cool think finally ready switch apple music"

# %%
import inflect
p = inflect.engine()

def print_recommendations(first_tweet, recommend_list):
    print('NEW MESSAGE:', first_tweet)
    i = 1
    for resp in df_ticket.loc[rec_list]['case_id']:
        print(f'\n---{p.ordinal(i)} SIMILAR CONVERSATION---\n')
        display_conversation(resp)
        print('\n')
        i += 1

# %%
rec_list = get_recommendations(df_ticket.text[0], lsa_tfidf, tfidf_vectorizer, lsa_tfidf_data)
print_recommendations(df_ticket.text[0], rec_list)
# Out:
# NEW MESSAGE: uh limit songs `` save '' — supposed track albums like cool cool cool think finally ready switch apple music
#
# ---1st SIMILAR CONVERSATION---
#
# CUSTOMER:    uh why is there a limit on how many songs i can "save" — how am i supposed to keep track of the albums i like?
# AGENT:       hey nick! there is currently a 10k limit in your music (songs + albums + artists). more info here: /mo
# CUSTOMER:    cool cool cool i think i am finally ready to switch to apple music
# AGENT:       sorry to hear you feel that way. for now, you can vote for the idea here: and get support from other users /mo
#
#
#
# ---2nd SIMILAR CONVERSATION---
#
# CUSTOMER:    you are cool, spotify.
# AGENT:       hey alice! thanks. you are not wrong, things sure are cooling down around the office. brr...
#
#
#
# ---3rd SIMILAR CONVERSATION---
#
# CUSTOMER:    this is cool
# AGENT:       thanks for the feedback, sara! it is music to our ears if there is anything we can help with, feel free to send us a tweet. /je

# %%
def display_conversation (case_id):
    cust_conv = ticket[ticket['case_id'] == case_id][['created_at', 'inbound', 'text']]
    agent_conv = solution[solution['case_id'] == case_id][['created_at', 'inbound', 'text']]
    conv_list = pd.concat([cust_conv, agent_conv]).sort_values('created_at')
    for i in range(conv_list.shape[0]):
        if (conv_list.iloc[i]['inbound']):
            print ('CUSTOMER:   ', colored(conv_list.iloc[i]['text'], 'red'))
        else:
            print ('AGENT:      ', colored(conv_list.iloc[i]['text'], 'green'))
